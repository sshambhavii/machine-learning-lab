# %%
import pandas as pd

# %%
salary_csv=pd.read_csv('MBA Salary.csv')

# %%
salary_csv.head(5)
# Out:
#    S. No.  Percentage in Grade 10  Salary
# 0       1                   62.00  270000
# 1       2                   76.33  200000
# 2       3                   72.00  240000
# 3       4                   60.00  250000
# 4       5                   61.00  180000

# %%
salary_csv.tail(5)
# Out:
#     S. No.  Percentage in Grade 10  Salary
# 45      46                   57.58  180000
# 46      47                   68.00  180000
# 47      48                   69.00  270000
# 48      49                   66.00  240000
# 49      50                   60.80  300000

# %%
list(salary_csv.columns)
# Out:
# ['S. No.', 'Percentage in Grade 10', 'Salary']

# %%
salary_csv.shape
# Out:
# (50, 3)

# %%
salary_csv.info
# Out:
# <bound method DataFrame.info of     S. No.  Percentage in Grade 10  Salary
# 0        1                   62.00  270000
# 1        2                   76.33  200000
# 2        3                   72.00  240000
# 3        4                   60.00  250000
# 4        5                   61.00  180000
# 5        6                   55.00  300000
# 6        7                   70.00  260000
# 7        8                   68.00  235000
# 8        9                   82.80  425000
# 9       10                   59.00  240000
# 10      11                   58.00  250000
# 11      12                   60.00  180000
# 12      13                   66.00  428000
# 13      14                   83.00  450000
# 14      15                   68.00  300000
# 15      16                   37.33  240000
# 16      17                   79.00  252000
# 17      18                   68.40  280000
# 18      19                   70.00  231000
# 19      20                   59.00  224000
# ...

# %%
salary_csv[0:10]
# Out:
#    S. No.  Percentage in Grade 10  Salary
# 0       1                   62.00  270000
# 1       2                   76.33  200000
# 2       3                   72.00  240000
# 3       4                   60.00  250000
# 4       5                   61.00  180000
# 5       6                   55.00  300000
# 6       7                   70.00  260000
# 7       8                   68.00  235000
# 8       9                   82.80  425000
# 9      10                   59.00  240000

# %%
salary_csv['Salary'][0:10]
# Out:
# 0    270000
# 1    200000
# 2    240000
# 3    250000
# 4    180000
# 5    300000
# 6    260000
# 7    235000
# 8    425000
# 9    240000
# Name: Salary, dtype: int64

# %%
salary_csv.Salary.value_counts()
# Out:
# 300000    6
# 250000    5
# 180000    5
# 240000    4
# 200000    3
# 360000    3
# 120000    3
# 270000    2
# 260000    2
# 265000    2
# 218000    1
# 236000    1
# 177600    1
# 340000    1
# 330000    1
# 150000    1
# 280000    1
# 224000    1
# 231000    1
# 252000    1
# 450000    1
# 428000    1
# 425000    1
# 235000    1
# 393000    1
# Name: Salary, dtype: int64

# %%
pd.crosstab(salary_csv['Salary'],salary_csv['Percentage in Grade 10'])
# Out:
# Percentage in Grade 10  37.33  49.00  50.00  50.08  52.00  54.00  55.00  \
# Salary
# 120000                      0      1      0      0      1      0      0
# 150000                      0      0      0      0      0      0      0
# 177600                      0      0      0      0      0      0      0
# 180000                      0      0      1      0      0      0      0
# 200000                      0      0      0      0      1      0      0
# 218000                      0      0      0      0      0      0      0
# 224000                      0      0      0      0      0      0      0
# 231000                      0      0      0      0      0      0      0
# 235000                      0      0      0      0      0      0      0
# 236000                      0      0      0      0      1      0      0
# 240000                      1      0      0      0      0      0      0
# 250000                      0      0      0      0      0      0      0
# ...

# %%
salary_csv['Salary'].mean()
# Out:
# 258192.0

# %%
salary_csv.groupby('Salary')['Percentage in Grade 10'].mean()
# Out:
# Salary
# 120000    54.666667
# 150000    67.000000
# 177600    68.000000
# 180000    59.316000
# 200000    62.776667
# 218000    74.000000
# 224000    59.000000
# 231000    70.000000
# 235000    68.000000
# 236000    52.000000
# 240000    58.582500
# 250000    66.420000
# 252000    79.000000
# 260000    60.000000
# 265000    52.040000
# 270000    65.500000
# 280000    68.400000
# 300000    63.700000
# 330000    78.000000
# 340000    56.000000
# 360000    65.433333
# 393000    76.000000
# 425000    82.800000
# 428000    66.000000
# 450000    83.000000
# Name: Percentage in Grade 10, dtype: float64
